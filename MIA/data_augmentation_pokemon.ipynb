# %% [markdown]
# # Introducció a l'augment de dades
#
# Augment de dades abans de l'entrenament

# %% [markdown]
# ## Imports

# %%
import os
import cv2
import matplotlib.pyplot as plt
import random
import pandas as pd
from PIL import Image
# Out:
# C:\Users\rmate\AppData\Local\Temp\ipykernel_10112\1786989038.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
BASE_PATH = "dataset_lab3\\images"
BASE_PATH_DA = "dataset_lab3\\da_images"

# %% [markdown]
# Funcions per iterar sobre diferents fitxers i obtenir tots els path

# %%
images = os.listdir(BASE_PATH)
for image in os.listdir(BASE_PATH):
    path_image = os.path.join(BASE_PATH, image)
    image_name = image.split(".")[0]
    image = Image.open(path_image)
    image_rotated_1 = image.rotate(random.randint(-180, 180))
    image_rotated_2 = image.rotate(random.randint(-180, 180))
    
    image.save(os.path.join(BASE_PATH_DA, image_name + "_original.png"))
    image_rotated_1.save(os.path.join(BASE_PATH_DA, image_name + "_rotated_1.png"))
    image_rotated_2.save(os.path.join(BASE_PATH_DA, image_name + "_rotated_2.png"))

# %%
data = pd.read_csv("dataset_lab3\pokemon.csv")
llista_pokemons = []
for row in data.iterrows():
    tipus = row[1][1]
    if os.path.exists('dataset_lab3\\images\\' + row[1][0] + '.png'):
        paht_image = 'dataset_lab3\\images\\' + row[1][0] + '.png'
    else:
        path_image = 'dataset_lab3\\images\\' + row[1][0] + '.jpg.png'
    
    llista_pokemons.append([path_image, tipus])
    llista_pokemons.append([image_rotated, tipus])
    #total_images.append(image)
# Out:
# C:\Users\rmate\AppData\Local\Temp\ipykernel_10112\2012938489.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(row[1][1])
# C:\Users\rmate\AppData\Local\Temp\ipykernel_10112\2012938489.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if os.path.exists('dataset_lab3\\images\\' + row[1][0] + '.png'):
# C:\Users\rmate\AppData\Local\Temp\ipykernel_10112\2012938489.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...
